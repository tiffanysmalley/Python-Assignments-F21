# %% [markdown]
# ## Week 6 Assignment - W200 Introduction to Data Science Programming, UC Berkeley MIDS
#
# Write code in this Jupyter Notebook to solve each of the following problems. Each problem should have its solution in a separate cell. Please upload this **notebook**, your **scrabble.py** file, the **sowpods.txt** file, and your **score_word** module to your GitHub repository in your SUBMISSIONS/week_06 folder by 11:59PM PST the night before class.

# %% [markdown]
# ## Objectives:
#
# - Read and understand PEP 8 standards
# - Use all of your previously gained knowledge together on a single program
# - Demonstrate how to import a user made module and function into python from another .py file
# - Demonstrate how to input command line arguments into a .py file

# %% [markdown]
# ## 6-1. PEP 8 Style Guide (reading and response) (10 points)
#
# Your first task for this week is to write a **250 word reading response** to the article referenced below. In addition, please list **3 questions** that you have from the article (the questions do not count towards the 250 word requirement). Please write your response in the markdown cell below.
#
# The writing response is a free response, so you may write about your reactions, such as an interesting thing that you saw in the article, something that really stuck out to you, etc.
#
# **Article**: [The PEP 8 Style Guide](https://www.python.org/dev/peps/pep-0008). This document is really important for Python coders because it describes best practices and customs.

# %% [markdown]
# A standardized style guide exists to influence programmers to code in a way that is easy read by others. It is also important that programmers are able to come back to their own code and quickly pick up where they left off and fix bugs as they arise. This document immediately highlighted three interesting, yet basic conventions that raised some thoughts:
#
# Indentation: While I think indentation is a great way to make code readable, it can cause issues and bugs that may be hard to track down without an IDE that highlights these issues for you. It was a slight challenge to get used to this standard, coming from the Java and C++ languages where this sort of functionality is syntax-dependent (for example, the equivalent of an indent after a conditional statement in Java would be a bracket- spaces or indents are disregarded). I was surprised to read that spaces are the preferred indentation method - using Jupyter Notebooks has made it easy just to use the tab button but I imagine it would be a difficult shift if, suddenly for some reason, I only had something like Vim.
#
# Maximum Line Length: While I was generally aware that one should avoid excessively long lines, this standard (79 chars, or 72 for flowing long blocks of text) was a helpful, specific measure to commit to memory. Jupyter could be improved by adding some feature to highlight lines that exceed this limit (like Atom).
#
# Comments: I didn't know comments should, ideally, be complete sentences or that the first word should be capitalized. To meet line length requirements, and enhance readability, I tend to keep them short and sweet, but will certainly work to improve the quality of my comments.
#
# Questions:
#
# - Is the indentation standard a reasonable tradeoff between readability and bug-prone functionality?
# - How do you make comments readable yet as formalized as the reading suggestions?
# - What IDEs best support adherence to the standards highlighted in the reading?

# %% [markdown]
# ## 6-2. Cheating at Scrabble (90 points + 10 Extra Credit Points)
#
# Write a Python program that takes a Scrabble rack as a command-line argument and prints all "valid Scrabble English" words that can be constructed from that rack, along with their Scrabble scores, sorted by score. "valid Scrabble English" words are provided in the data source below. A Scrabble rack is made up of 2 to 7 characters.
#
# Below are the requirements for the program:
# - This needs to be able to be run as a command line tool as shown below (not an input statement!)
# - Name the python file: `scrabble.py`
# - Make a separate module named `wordscore` which contains at a minimum a function called `score_word`. This `score_word` function will take each word and return the score (scoring dictionary is described below). Import this function into your main `scrabble.py` program.
# - Allow anywhere from 2-7 character tiles (letters A-Z) to be inputted.
# - Do not restrict the number of same tiles (e.g., a user is allowed to input ZZZZZQQ).
# - Output the **total** list of valid Scrabble words that can be constructed from the rack as (score, word) tuples, sorted by the score and then by the word alphabetically as shown in the first example below.
# - Then output 'Total number of words:' and the total number.
# - You need to handle input errors from the user and suggest what that error might be caused by and how to fix it (i.e., a helpful error message)
# - Implement wildcards as either `*` or `?`. There can be a total of **only** two wild cards in any user input (that is, one of each character: one `*` and one `?`). Only use the `*` and `?` as wildcard characters. A wildcard character can take any value A-Z. Replace the wildcard symbol with the letter in your answer (see the second example below).
# - Wildcard characters are scored as 0 points, just like in the real Scrabble game. A two wildcard word can be made, should be outputted and scored as 0 points.
#   - In a wildcard case where the same word can be made with or without the wildcard, display the highest score. For example: given the input 'I?F', the word 'if' can be made with the wildcard '?F' as well as the letters 'IF'. Since using the letters 'IF' scores higher, display that score.
# - For partial credit, your program should take less than one minute to run with 2 wildcards in the input. For full credit, the program needs to run with 2 wildcards in less than 30 seconds.
# - Write docstrings for the functions and puts comments in your code.
# - You may only use the Python standard library in this assignment. However, any function in the standard library is allowed.
#
# An example invocation and output:
# ```
# $ python scrabble.py "ZAEFIEE"
# (17, feaze)
# (17, feeze)
# (16, faze)
# (15, fez)
# (15, fiz)
# (12, zea)
# (12, zee)
# (11, za)
# (6, fae)
# (6, fee)
# (6, fie)
# (5, ef)
# (5, fa)
# (5, fe)
# (5, if)
# (2, ae)
# (2, ai)
# (2, ea)
# (2, ee)
# Total number of words: 19
# ```
#
# An example wildcard invocation and output:
# ```
# $ python scrabble.py "?F"
# (4, ef)
# (4, fa)
# (4, fe)
# (4, fy)
# (4, if)
# (4, of)
# Total number of words: 6
# ```
#
# #### Extra Credit (+10 points):
# Requirements:
# - Allow a user to specify that a certain letter has to be at a certain location. For the extra credit, locations of certain letters must be specified at the command line, and may not be some sort of user prompt. How you do this is up to you!
# - This needs to be included and called from your regular scrabble.py file and work with the base requirements above. That is, your program must work with or without the extra credit portion and the extra credit cannot be in a different .py file.
# - Please put comments, any assumptions you made, and a sample of how to run your extra credit in the extra credit cell of this notebook below - it is the last cell. If there is not an example of how to run the extra credit in this cell we will assume that you did not do the extra credit part!
#
# #### The Data
# The file: http://courses.cms.caltech.edu/cs11/material/advjava/lab1/sowpods.zip or https://drive.google.com/file/d/1ewUiZL_4HanCDsaYB5pcKEgqjMFVgGnh/view?usp=sharing contains all "valid Scrabble English" words in the official words list, one word per line. You should download the word file and keep it in your repository so that the program is standalone (instead of accessing it over the web from Python).
#
# You can read data from a text file with the following code:
# ```
# with open("sowpods.txt","r") as infile:
#     raw_input = infile.readlines()
#     data = [datum.strip('\n') for datum in raw_input]
# ```
#
# This will show the first 6 words:
# ```
# print(data[0:6])
# ```
# Please use the dictionary below containing the letters and their Scrabble values:
# ```
# scores = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2,
#          "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3,
#          "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,
#          "r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,
#          "x": 8, "z": 10}
# ```
#
# #### Tips:
# - If you don't know what "scrabble" is or the basic background of the game please look it up online!
# - We recommend that you try to break down the problem into steps on your own before writing any code. Once you've scoped generally what you want to do, then start writing some code.  If you get stuck, go back to thinking about the problem rather than trying to fix lots of errors at the code level.
# - If you have questions on getting arguments from the command line, please review async video 6.17 and Drill 6.18.
# - If you keep getting stuck, then check out: https://wiki.openhatch.org/wiki/Scrabble_challenge or https://drive.google.com/file/d/1g3yz5ljkzaAeQ-AgQR1Hofy8ZJ0jo25x/view?usp=sharing. This is where we got the idea for this assignment and it provides some helpful tips for guiding you along the way.  However, we would recommend that you try to implement this first before looking at the hints on the website.
#
# Good luck!

# %% [markdown]
# ### The code below will test your command line implementation of the scrabble.py code. We've made some of these tests available for you to try!

# %%
# Code for the testing

import subprocess
from nose.tools import assert_equal 
from nose.tools import assert_true
from nose.tools import assert_greater
from nose.tools import assert_less

# %%
""" Code runs and can produce at least one error message """
# Autograde cell - do not erase/delete

# no rack error
# !python scrabble.py
# Out:
# No input recieved.

# %%
""" Does not fail due to trivial mistakes and takes correct wildcard characters """
# Autograde cell - do not erase/delete

# does not fail due to case
# !python scrabble.py "PENguin"
# Out:
# (10, penguin)
# (9, pening)
# (8, genip)
# (8, unpeg)
# (7, ingenu)
# (7, penni)
# (7, ping)
# (7, pung)
# (7, unpen)
# (7, unpin)
# (6, gip)
# (6, gup)
# (6, peg)
# (6, pein)
# (6, peni)
# (6, pig)
# (6, pine)
# (6, pug)
# (5, ennui)
# (5, genu)
# (5, gien)
# (5, ginn)
# (5, nep)
# (5, nip)
# (5, pen)
# (5, pie)
# (5, pin)
# (5, piu)
# (5, pun)
# (4, eng)
# (4, gen)
# (4, gie)
# (4, gin)
# (4, gnu)
# (4, gue)
# (4, gun)
# (4, neg)
# (4, nine)
# (4, pe)
# (4, pi)
# (4, up)
# (3, gi)
# (3, gu)
# (3, inn)
# (3, nie)
# (3, nun)
# (3, ug)
# (3, uni)
# (2, en)
# (2, in)
# (2, ne)
# (2, nu)
# (2, un)
# Total number of words: 53

# %%
# Autograde cell - do not erase/delete

# takes wildcards

# !python scrabble.py "PEN*?in"
# Out:
# (7, aa)
# (7, ab)
# (7, ace)
# (7, acne)
# (7, ad)
# (7, ae)
# (7, aeon)
# (7, ag)
# (7, age)
# (7, agen)
# (7, agin)
# (7, ah)
# (7, ahi)
# (7, ai)
# (7, aia)
# (7, aid)
# (7, aide)
# (7, ail)
# (7, aim)
# (7, ain)
# (7, aine)
# (7, ainee)
# (7, ains)
# (7, air)
# (7, airn)
# (7, ais)
# (7, ait)
# (7, ake)
# (7, akin)
# (7, al)
# (7, ale)
# (7, alien)
# (7, aline)
# (7, alp)
# (7, alpine)
# (7, am)
# (7, amen)
# (7, ami)
# (7, amie)
# (7, amin)
# (7, amine)
# (7, amp)
# (7, an)
# (7, ana)
# (7, anan)
# (7, ance)
# (7, and)
# (7, ane)
# (7, anent)
# (7, anes)
# (7, anew)
# (7, ani)
# (7, anil)
# (7, anile)
# (7, anime)
# (7, anion)
# (7, anis)
# (7, anise)
# (7, ann)
# (7, anna)
# (7, annex)
# (7, anno)
# (7, anns)
# (7, anon)
# (7, ant)
# (7, ante)
# (7, anti)
# (7, any)
# (7, ape)
# (7, aped)
# (7, aper)
# (7, apes)
# (7, apex)
# (7, apian)
# (7, aping)
# (7, apnea)
# (7, apneic)
# (7, apo)
# (7, app)
# (7, apse)
# (7, apt)
# (7, ar)
# (7, are)
# (7, arpen)
# (7, as)
# (7, asp)
# (7, aspen)
# (7, aspine)
# (7, at)
# (7, ate)
# (7, aue)
# (7, aune)
# (7, ave)
# (7, avine)
# (7, aw)
# (7, awe)
# (7, awn)
# (7, ax)
# (7, axe)
# (7, ay)
# (7, aye)
# (7, ayin)
# (7, azine)
# (7, ba)
# (7, ban)
# (7, bane)
# (7, bani)
# (7, bap)
# (7, be)
# (7, bean)
# (7, bed)
# (7, bee)
# (7, been)
# (7, beep)
# (7, beg)
# (7, begin)
# (7, bein)
# (7, being)
# (7, bel)
# (7, ben)
# (7, bend)
# (7, bene)
# (7, beni)
# (7, benign)
# (7, benis)
# (7, benj)
# (7, benne)
# (7, benni)
# (7, bennis)
# (7, benny)
# (7, bens)
# (7, bent)
# (7, benzin)
# (7, bes)
# (7, bet)
# (7, bey)
# (7, bez)
# (7, bi)
# (7, bib)
# (7, bice)
# (7, bicep)
# (7, bid)
# (7, bide)
# (7, bien)
# (7, bier)
# (7, big)
# (7, bike)
# (7, bile)
# (7, bin)
# (7, bind)
# (7, bine)
# (7, biner)
# (7, bines)
# (7, bing)
# (7, binge)
# (7, bink)
# (7, binmen)
# (7, binned)
# (7, bins)
# (7, bint)
# (7, bio)
# (7, biped)
# (7, bis)
# (7, bise)
# (7, bit)
# (7, bite)
# (7, biz)
# (7, bize)
# (7, blin)
# (7, blip)
# (7, bo)
# (7, boep)
# (7, boi)
# (7, bon)
# (7, bone)
# (7, bonie)
# (7, bonne)
# (7, bonnie)
# (7, bop)
# (7, brei)
# (7, bren)
# (7, brie)
# (7, brin)
# (7, brine)
# (7, bun)
# (7, bunn)
# (7, by)
# (7, bye)
# (7, cain)
# (7, can)
# (7, cane)
# (7, canine)
# (7, cann)
# (7, cannie)
# (7, cap)
# (7, cape)
# (7, capi)
# (7, cedi)
# (7, cee)
# (7, ceil)
# (7, cel)
# (7, cens)
# (7, cent)
# (7, cep)
# (7, cepe)
# (7, ceps)
# (7, ch)
# (7, che)
# (7, chi)
# (7, chin)
# (7, chine)
# (7, chip)
# (7, cid)
# (7, cide)
# (7, ciel)
# (7, cig)
# (7, cine)
# (7, cines)
# (7, cion)
# (7, cire)
# (7, cis)
# (7, cit)
# (7, cite)
# (7, cive)
# (7, cline)
# (7, clip)
# (7, clipe)
# (7, coin)
# (7, con)
# (7, cone)
# (7, coni)
# (7, conin)
# (7, conine)
# (7, conn)
# (7, conne)
# (7, cop)
# (7, cope)
# (7, copen)
# (7, crine)
# (7, cripe)
# (7, cue)
# (7, cunei)
# (7, cup)
# (7, da)
# (7, dae)
# (7, daine)
# (7, dan)
# (7, dap)
# (7, de)
# (7, dean)
# (7, deb)
# (7, dee)
# (7, deen)
# (7, deep)
# (7, def)
# (7, defi)
# (7, deg)
# (7, dei)
# (7, deid)
# (7, deif)
# (7, deign)
# (7, deil)
# (7, del)
# (7, deli)
# (7, den)
# (7, dene)
# (7, deni)
# (7, denim)
# (7, denis)
# (7, dens)
# (7, dent)
# (7, dentin)
# (7, deny)
# (7, dern)
# (7, desi)
# (7, dev)
# (7, dew)
# (7, dex)
# (7, dey)
# (7, di)
# (7, dib)
# (7, dice)
# (7, did)
# (7, die)
# (7, dieb)
# (7, died)
# (7, diel)
# (7, diene)
# (7, dies)
# (7, diet)
# (7, dif)
# (7, dig)
# (7, dike)
# (7, dim)
# (7, dime)
# (7, dimp)
# (7, din)
# (7, dine)
# (7, dined)
# (7, diner)
# (7, dines)
# (7, ding)
# (7, dinge)
# (7, dink)
# (7, dinna)
# (7, dinned)
# (7, dinner)
# (7, dinnle)
# (7, dino)
# (7, dins)
# (7, dint)
# (7, dip)
# (7, dipnet)
# (7, dips)
# (7, dipt)
# (7, dire)
# (7, dis)
# (7, dit)
# (7, dite)
# (7, div)
# (7, dive)
# (7, dizen)
# (7, djin)
# (7, djinn)
# (7, do)
# (7, doe)
# (7, doen)
# (7, don)
# (7, done)
# (7, donne)
# (7, dop)
# (7, dope)
# (7, drip)
# (7, due)
# (7, dui)
# (7, dun)
# (7, dune)
# (7, dup)
# (7, dupe)
# (7, dwine)
# (7, dye)
# (7, dyne)
# (7, dynein)
# (7, ea)
# (7, ean)
# (7, eaning)
# (7, eans)
# (7, ear)
# (7, earn)
# (7, eas)
# (7, eat)
# (7, eau)
# (7, ebb)
# (7, ebon)
# (7, ech)
# (7, eco)
# (7, ecu)
# (7, ed)
# (7, edh)
# (7, edit)
# (7, eds)
# (7, ee)
# (7, eek)
# (7, eel)
# (7, een)
# (7, eevn)
# (7, ef)
# (7, eff)
# (7, efs)
# (7, eft)
# (7, egg)
# (7, egis)
# (7, ego)
# (7, eh)
# (7, ehing)
# (7, ehs)
# (7, eide)
# (7, eigne)
# (7, eik)
# (7, eikon)
# (7, eiks)
# (7, eild)
# (7, eina)
# (7, eine)
# (7, eish)
# (7, eke)
# (7, eking)
# (7, el)
# (7, elain)
# (7, elan)
# (7, eld)
# (7, eldin)
# (7, elf)
# (7, elfin)
# (7, elhi)
# (7, elint)
# (7, elk)
# (7, ell)
# (7, elm)
# (7, eloin)
# (7, els)
# (7, elsin)
# (7, elt)
# (7, em)
# (7, eme)
# (7, emic)
# (7, emir)
# (7, emit)
# (7, emo)
# (7, empt)
# (7, ems)
# (7, emu)
# (7, en)
# (7, encina)
# (7, end)
# (7, ending)
# (7, endrin)
# (7, ends)
# (7, ene)
# (7, enes)
# (7, enew)
# (7, enfix)
# (7, eng)
# (7, engine)
# (7, engs)
# (7, eniac)
# (7, enjoin)
# (7, enlink)
# (7, enlit)
# (7, ennog)
# (7, ennui)
# (7, ennuis)
# (7, enoki)
# (7, enol)
# (7, enow)
# (7, enprint)
# (7, enring)
# (7, ens)
# (7, ensign)
# (7, entia)
# (7, enuf)
# (7, envoi)
# (7, envy)
# (7, enwind)
# (7, enzian)
# (7, eoan)
# (7, eon)
# (7, eonian)
# (7, eons)
# (7, eosin)
# (7, epee)
# (7, epha)
# (7, epic)
# (7, epics)
# (7, epigon)
# (7, epos)
# (7, epris)
# (7, equip)
# (7, er)
# (7, era)
# (7, ere)
# (7, erf)
# (7, erg)
# (7, eric)
# (7, ering)
# (7, erk)
# (7, ern)
# (7, erne)
# (7, erning)
# (7, erns)
# (7, err)
# (7, ers)
# (7, es)
# (7, esne)
# (7, espy)
# (7, ess)
# (7, est)
# (7, et)
# (7, eta)
# (7, eten)
# (7, eth)
# (7, etic)
# (7, etna)
# (7, ettin)
# (7, etui)
# (7, euk)
# (7, euoi)
# (7, eve)
# (7, even)
# (7, evil)
# (7, evo)
# (7, ewe)
# (7, ewk)
# (7, ewt)
# (7, ex)
# (7, exine)
# (7, exing)
# (7, exit)
# (7, exo)
# (7, exon)
# (7, expo)
# (7, eye)
# (7, eyen)
# (7, eying)
# (7, eyne)
# (7, fa)
# (7, fae)
# (7, fain)
# (7, faine)
# (7, fainne)
# (7, fan)
# (7, fane)
# (7, fap)
# (7, fe)
# (7, fed)
# (7, fee)
# (7, feen)
# (7, feg)
# (7, feh)
# (7, feign)
# (7, feint)
# (7, feis)
# (7, fem)
# (7, fen)
# (7, fend)
# (7, feni)
# (7, fenis)
# (7, fenny)
# (7, fens)
# (7, fent)
# (7, fer)
# (7, fern)
# (7, fes)
# (7, fet)
# (7, feu)
# (7, few)
# (7, fey)
# (7, fez)
# (7, fib)
# (7, fice)
# (7, fid)
# (7, fie)
# (7, fief)
# (7, fiend)
# (7, fient)
# (7, fier)
# (7, fife)
# (7, fig)
# (7, fike)
# (7, fil)
# (7, file)
# (7, fin)
# (7, find)
# (7, fine)
# (7, fined)
# (7, finer)
# (7, fines)
# (7, fini)
# (7, fink)
# (7, finned)
# (7, finner)
# (7, finny)
# (7, fino)
# (7, fins)
# (7, fir)
# (7, fire)
# (7, firn)
# (7, fit)
# (7, five)
# (7, fix)
# (7, fiz)
# (7, flip)
# (7, foe)
# (7, foen)
# (7, foin)
# (7, fon)
# (7, fone)
# (7, fop)
# (7, fun)
# (7, fy)
# (7, gae)
# (7, gaen)
# (7, gain)
# (7, gan)
# (7, gane)
# (7, gap)
# (7, gape)
# (7, gean)
# (7, ged)
# (7, gee)
# (7, geep)
# (7, geit)
# (7, gel)
# (7, gem)
# (7, gen)
# (7, gena)
# (7, gene)
# (7, genic)
# (7, genie)
# (7, genii)
# (7, genip)
# (7, genips)
# (7, genny)
# (7, gens)
# (7, gent)
# (7, genu)
# (7, geo)
# (7, get)
# (7, gey)
# (7, ghi)
# (7, gi)
# (7, gib)
# (7, gibe)
# (7, gid)
# (7, gie)
# (7, gied)
# (7, gien)
# (7, gies)
# (7, gif)
# (7, gig)
# (7, gimp)
# (7, gin)
# (7, ging)
# (7, ginge)
# (7, gink)
# (7, ginn)
# (7, ginned)
# (7, ginnel)
# (7, ginner)
# (7, ginny)
# (7, gins)
# (7, gio)
# (7, gip)
# (7, gipon)
# (7, gips)
# (7, gipsen)
# (7, girn)
# (7, gis)
# (7, git)
# (7, gite)
# (7, give)
# (7, given)
# (7, glei)
# (7, glen)
# (7, gnu)
# (7, go)
# (7, goe)
# (7, gon)
# (7, gone)
# (7, grein)
# (7, gren)
# (7, grin)
# (7, grip)
# (7, gripe)
# (7, gu)
# (7, gue)
# (7, gun)
# (7, gup)
# (7, gwine)
# (7, gynie)
# (7, gyp)
# (7, ha)
# (7, hae)
# (7, haen)
# (7, hain)
# (7, han)
# (7, hap)
# (7, he)
# (7, heap)
# (7, heh)
# (7, heid)
# (7, heil)
# (7, heir)
# (7, help)
# (7, hem)
# (7, hemin)
# (7, hemp)
# (7, hen)
# (7, hend)
# (7, henna)
# (7, hennin)
# (7, henny)
# (7, hens)
# (7, hent)
# (7, hep)
# (7, heps)
# (7, hept)
# (7, her)
# (7, hern)
# (7, hes)
# (7, hesp)
# (7, het)
# (7, hew)
# (7, hewn)
# (7, hex)
# (7, hey)
# (7, hi)
# (7, hic)
# (7, hid)
# (7, hide)
# (7, hie)
# (7, hied)
# (7, hies)
# (7, hike)
# (7, him)
# (7, hin)
# (7, hind)
# (7, hing)
# (7, hinge)
# (7, hinny)
# (7, hins)
# (7, hint)
# (7, hip)
# (7, hippen)
# (7, hips)
# (7, hipt)
# (7, hire)
# (7, his)
# (7, hisn)
# (7, hit)
# (7, hive)
# (7, hizen)
# (7, hm)
# (7, ho)
# (7, hoe)
# (7, hoi)
# (7, hon)
# (7, hone)
# (7, hop)
# (7, hope)
# (7, hue)
# (7, hui)
# (7, hun)
# (7, hup)
# (7, hye)
# (7, hyen)
# (7, hyp)
# (7, hype)
# (7, ibex)
# (7, ice)
# (7, iced)
# (7, icer)
# (7, ices)
# (7, ich)
# (7, ick)
# (7, icon)
# (7, icy)
# (7, id)
# (7, ide)
# (7, idea)
# (7, idee)
# (7, idem)
# (7, ident)
# (7, ides)
# (7, idle)
# (7, ids)
# (7, if)
# (7, iff)
# (7, ifs)
# (7, igg)
# (7, ikan)
# (7, ikon)
# (7, ilea)
# (7, ilex)
# (7, ilk)
# (7, ill)
# (7, imine)
# (7, imp)
# (7, imped)
# (7, impel)
# (7, impend)
# (7, impi)
# (7, impone)
# (7, imps)
# (7, in)
# (7, inane)
# (7, inaner)
# (7, inanes)
# (7, inapt)
# (7, inbent)
# (7, inby)
# (7, inbye)
# (7, incent)
# (7, incept)
# (7, inch)
# (7, incle)
# (7, indene)
# (7, indent)
# (7, indew)
# (7, index)
# (7, indie)
# (7, indue)
# (7, inept)
# (7, inerm)
# (7, inert)
# (7, infer)
# (7, info)
# (7, ingan)
# (7, ingenu)
# (7, ingine)
# (7, ingle)
# (7, ingo)
# (7, inia)
# (7, inion)
# (7, ink)
# (7, inked)
# (7, inker)
# (7, inkle)
# (7, inks)
# (7, inky)
# (7, inlet)
# (7, inly)
# (7, inn)
# (7, innage)
# (7, innate)
# (7, inned)
# (7, inner)
# (7, inners)
# (7, inns)
# (7, input)
# (7, inro)
# (7, inrun)
# (7, ins)
# (7, insane)
# (7, inset)
# (7, inspan)
# (7, instep)
# (7, intel)
# (7, intend)
# (7, intent)
# (7, inter)
# (7, intern)
# (7, inti)
# (7, intine)
# (7, into)
# (7, intone)
# (7, inure)
# (7, inurn)
# (7, invent)
# (7, io)
# (7, ion)
# (7, ionone)
# (7, ions)
# (7, ios)
# (7, ippon)
# (7, ire)
# (7, ired)
# (7, ires)
# (7, irk)
# (7, iron)
# (7, irone)
# (7, is)
# (7, ish)
# (7, isle)
# (7, ism)
# (7, isna)
# (7, isnae)
# (7, iso)
# (7, it)
# (7, ita)
# (7, item)
# (7, its)
# (7, iure)
# (7, ivy)
# (7, iwi)
# (7, ja)
# (7, jai)
# (7, jane)
# (7, jann)
# (7, jap)
# (7, jape)
# (7, jean)
# (7, jedi)
# (7, jee)
# (7, jeep)
# (7, jenny)
# (7, jeon)
# (7, jet)
# (7, jeu)
# (7, jew)
# (7, jib)
# (7, jibe)
# (7, jig)
# (7, jimp)
# (7, jin)
# (7, jink)
# (7, jinn)
# (7, jinne)
# (7, jinnee)
# (7, jinni)
# (7, jinns)
# (7, jins)
# (7, jinx)
# (7, jive)
# (7, jiz)
# (7, jo)
# (7, joe)
# (7, join)
# (7, jun)
# (7, jupe)
# (7, ka)
# (7, kae)
# (7, kai)
# (7, kaie)
# (7, kain)
# (7, kane)
# (7, kea)
# (7, keb)
# (7, ked)
# (7, keen)
# (7, keep)
# (7, kef)
# (7, keg)
# (7, keir)
# (7, kelp)
# (7, kemp)
# (7, ken)
# (7, keno)
# (7, kens)
# (7, kent)
# (7, kep)
# (7, kepi)
# (7, kepis)
# (7, keps)
# (7, kept)
# (7, kern)
# (7, ket)
# (7, kex)
# (7, key)
# (7, khi)
# (7, ki)
# (7, kibe)
# (7, kid)
# (7, kief)
# (7, kier)
# (7, kif)
# (7, kike)
# (7, kiln)
# (7, kilp)
# (7, kin)
# (7, kina)
# (7, kind)
# (7, kine)
# (7, kines)
# (7, king)
# (7, kinin)
# (7, kink)
# (7, kino)
# (7, kinone)
# (7, kins)
# (7, kip)
# (7, kipe)
# (7, kipes)
# (7, kipp)
# (7, kippen)
# (7, kips)
# (7, kir)
# (7, kirn)
# (7, kis)
# (7, kit)
# (7, kite)
# (7, knap)
# (7, knee)
# (7, knew)
# (7, knife)
# (7, knit)
# (7, knive)
# (7, knop)
# (7, ko)
# (7, koi)
# (7, koine)
# (7, kon)
# (7, kop)
# (7, kue)
# (7, kune)
# (7, ky)
# (7, kye)
# (7, kyne)
# (7, kype)
# (7, la)
# (7, lain)
# (7, lane)
# (7, lap)
# (7, lapin)
# (7, lea)
# (7, lean)
# (7, leap)
# (7, led)
# (7, lee)
# (7, leep)
# (7, leg)
# (7, lei)
# (7, leir)
# (7, leis)
# (7, lek)
# (7, lend)
# (7, leng)
# (7, lenis)
# (7, leno)
# (7, lens)
# (7, lent)
# (7, lenti)
# (7, lep)
# (7, lepid)
# (7, leps)
# (7, lept)
# (7, leptin)
# (7, lerp)
# (7, les)
# (7, let)
# (7, leu)
# (7, lev)
# (7, levin)
# (7, lew)
# (7, lex)
# (7, ley)
# (7, lez)
# (7, li)
# (7, liane)
# (7, lib)
# (7, lice)
# (7, lid)
# (7, lie)
# (7, lied)
# (7, lief)
# (7, lien)
# (7, liens)
# (7, lier)
# (7, lies)
# (7, lieu)
# (7, life)
# (7, lig)
# (7, ligne)
# (7, like)
# (7, liken)
# (7, lime)
# (7, limen)
# (7, limn)
# (7, limp)
# (7, lin)
# (7, lind)
# (7, linden)
# (7, line)
# (7, lined)
# (7, linen)
# (7, linens)
# (7, lineny)
# (7, liner)
# (7, lines)
# (7, lineup)
# (7, liney)
# (7, ling)
# (7, linin)
# (7, link)
# (7, linn)
# (7, linned)
# (7, linnet)
# (7, linney)
# (7, linns)
# (7, linny)
# (7, lino)
# (7, lins)
# (7, lint)
# (7, liny)
# (7, lion)
# (7, lip)
# (7, lipa)
# (7, lipe)
# (7, lipin)
# (7, lipo)
# (7, lippen)
# (7, lips)
# (7, lire)
# (7, lis)
# (7, lisp)
# (7, lit)
# (7, lite)
# (7, live)
# (7, liven)
# (7, lo)
# (7, loin)
# (7, loipe)
# (7, loipen)
# (7, lone)
# (7, lop)
# (7, lope)
# (7, lune)
# (7, lupin)
# (7, lupine)
# (7, lwei)
# (7, lye)
# (7, lyne)
# (7, ma)
# (7, mae)
# (7, main)
# (7, man)
# (7, mane)
# (7, mani)
# (7, map)
# (7, me)
# (7, mean)
# (7, med)
# (7, mee)
# (7, meg)
# (7, mein)
# (7, meins)
# (7, meint)
# (7, meiny)
# (7, mel)
# (7, mem)
# (7, men)
# (7, mend)
# (7, mene)
# (7, meng)
# (7, mening)
# (7, meninx)
# (7, meno)
# (7, ment)
# (7, menu)
# (7, meri)
# (7, mes)
# (7, met)
# (7, meu)
# (7, mew)
# (7, mi)
# (7, mib)
# (7, mic)
# (7, mice)
# (7, mid)
# (7, mien)
# (7, miens)
# (7, mig)
# (7, mike)
# (7, mil)
# (7, mile)
# (7, mim)
# (7, mime)
# (7, mina)
# (7, minae)
# (7, mince)
# (7, mind)
# (7, mine)
# (7, mined)
# (7, miner)
# (7, mines)
# (7, ming)
# (7, minge)
# (7, mini)
# (7, mink)
# (7, minke)
# (7, minnie)
# (7, minny)
# (7, mino)
# (7, mint)
# (7, minx)
# (7, miny)
# (7, mips)
# (7, mir)
# (7, mire)
# (7, mis)
# (7, mise)
# (7, mispen)
# (7, mite)
# (7, mix)
# (7, mixen)
# (7, miz)
# (7, mizen)
# (7, mm)
# (7, mna)
# (7, mo)
# (7, moe)
# (7, moi)
# (7, mon)
# (7, monie)
# (7, mop)
# (7, mope)
# (7, mu)
# (7, mun)
# (7, muni)
# (7, my)
# (7, na)
# (7, naan)
# (7, nab)
# (7, nabe)
# (7, nae)
# (7, naevi)
# (7, nag)
# (7, nah)
# (7, naif)
# (7, naik)
# (7, nail)
# (7, nain)
# (7, naive)
# (7, nam)
# (7, name)
# (7, nan)
# (7, nana)
# (7, nance)
# (7, nane)
# (7, nannie)
# (7, nans)
# (7, naoi)
# (7, nap)
# (7, napa)
# (7, nape)
# (7, naped)
# (7, napes)
# (7, naping)
# (7, napkin)
# (7, nappe)
# (7, nappie)
# (7, naps)
# (7, nare)
# (7, narine)
# (7, nas)
# (7, nat)
# (7, nave)
# (7, naw)
# (7, nay)
# (7, naze)
# (7, nazi)
# (7, ne)
# (7, neal)
# (7, neanic)
# (7, neap)
# (7, neaping)
# (7, neaps)
# (7, near)
# (7, neat)
# (7, neb)
# (7, nebs)
# (7, neck)
# (7, ned)
# (7, neds)
# (7, nee)
# (7, need)
# (7, neem)
# (7, neep)
# (7, neeps)
# (7, nef)
# (7, nefs)
# (7, neg)
# (7, negs)
# (7, neif)
# (7, neifs)
# (7, neigh)
# (7, neinei)
# (7, neist)
# (7, neive)
# (7, nek)
# (7, neks)
# (7, nelis)
# (7, nema)
# (7, nemn)
# (7, nemns)
# (7, nempt)
# (7, nene)
# (7, nenes)
# (7, neon)
# (7, neons)
# (7, nep)
# (7, neper)
# (7, nepit)
# (7, nepits)
# (7, neps)
# (7, nerd)
# (7, nerine)
# (7, nerk)
# (7, nesh)
# (7, ness)
# (7, nest)
# (7, net)
# (7, nete)
# (7, netop)
# (7, nets)
# (7, nett)
# (7, neuk)
# (7, neum)
# (7, neve)
# (7, nevi)
# (7, new)
# (7, newie)
# (7, newing)
# (7, news)
# (7, newt)
# (7, next)
# (7, nib)
# (7, nibs)
# (7, nice)
# (7, nicer)
# (7, niche)
# (7, nick)
# (7, nid)
# (7, nide)
# (7, nided)
# (7, nides)
# (7, nidi)
# (7, nids)
# (7, nie)
# (7, niece)
# (7, nied)
# (7, nief)
# (7, niefs)
# (7, nies)
# (7, nieve)
# (7, nife)
# (7, nifes)
# (7, niff)
# (7, niger)
# (7, nigh)
# (7, nil)
# (7, nill)
# (7, nils)
# (7, nim)
# (7, nimb)
# (7, nimps)
# (7, nims)
# (7, nine)
# (7, ninepin)
# (7, nines)
# (7, ninety)
# (7, ninja)
# (7, ninny)
# (7, ninon)
# (7, ninth)
# (7, nip)
# (7, nipa)
# (7, nipas)
# (7, nipped)
# (7, nipper)
# (7, nipple)
# (7, nippy)
# (7, nips)
# (7, nipter)
# (7, nirl)
# (7, nis)
# (7, nisei)
# (7, nish)
# (7, nisi)
# (7, nisse)
# (7, nit)
# (7, nite)
# (7, niter)
# (7, nites)
# (7, niton)
# (7, nitre)
# (7, nits)
# (7, nix)
# (7, nixe)
# (7, nixed)
# (7, nixer)
# (7, nixes)
# (7, nixie)
# (7, nixy)
# (7, no)
# (7, nob)
# (7, nod)
# (7, node)
# (7, nodi)
# (7, noel)
# (7, noes)
# (7, nog)
# (7, noh)
# (7, noil)
# (7, noint)
# (7, noir)
# (7, noise)
# (7, nole)
# (7, nom)
# (7, nome)
# (7, nomen)
# (7, non)
# (7, nona)
# (7, nonce)
# (7, none)
# (7, nones)
# (7, nonet)
# (7, nong)
# (7, noni)
# (7, nonis)
# (7, noo)
# (7, noon)
# (7, noop)
# (7, nope)
# (7, nor)
# (7, nori)
# (7, nos)
# (7, nose)
# (7, not)
# (7, note)
# (7, noun)
# (7, noup)
# (7, now)
# (7, nown)
# (7, nox)
# (7, noy)
# (7, nth)
# (7, nu)
# (7, nub)
# (7, nude)
# (7, nudie)
# (7, nuke)
# (7, numen)
# (7, nun)
# (7, nuns)
# (7, nur)
# (7, nus)
# (7, nut)
# (7, ny)
# (7, nye)
# (7, nyed)
# (7, nyes)
# (7, nying)
# (7, nys)
# (7, ob)
# (7, obe)
# (7, obi)
# (7, od)
# (7, ode)
# (7, oe)
# (7, oes)
# (7, of)
# (7, oh)
# (7, oi)
# (7, oik)
# (7, oil)
# (7, oink)
# (7, oint)
# (7, oke)
# (7, ole)
# (7, olein)
# (7, olpe)
# (7, om)
# (7, omen)
# (7, on)
# (7, once)
# (7, ondine)
# (7, one)
# (7, oner)
# (7, ones)
# (7, onie)
# (7, onion)
# (7, online)
# (7, onned)
# (7, ono)
# (7, ons)
# (7, ony)
# (7, oo)
# (7, oon)
# (7, oop)
# (7, op)
# (7, ope)
# (7, oped)
# (7, open)
# (7, opening)
# (7, opens)
# (7, opes)
# (7, opine)
# (7, opined)
# (7, opines)
# (7, oping)
# (7, ops)
# (7, opsin)
# (7, opt)
# (7, or)
# (7, ore)
# (7, orpin)
# (7, orpine)
# (7, os)
# (7, ose)
# (7, ou)
# (7, oup)
# (7, oven)
# (7, ovine)
# (7, ow)
# (7, owe)
# (7, own)
# (7, ox)
# (7, oxen)
# (7, oy)
# (7, oye)
# (7, pa)
# (7, pac)
# (7, pace)
# (7, pad)
# (7, padi)
# (7, paean)
# (7, paeon)
# (7, page)
# (7, pah)
# (7, paid)
# (7, paik)
# (7, pail)
# (7, pain)
# (7, pained)
# (7, pains)
# (7, paint)
# (7, pair)
# (7, paire)
# (7, pais)
# (7, paise)
# (7, pal)
# (7, pale)
# (7, pam)
# (7, pan)
# (7, pance)
# (7, pand)
# (7, pane)
# (7, paned)
# (7, panel)
# (7, panes)
# (7, pang)
# (7, pangen)
# (7, panic)
# (7, panier)
# (7, panim)
# (7, paning)
# (7, panini)
# (7, panino)
# (7, panne)
# (7, panned)
# (7, panner)
# (7, pannes)
# (7, pannier)
# (7, pans)
# (7, pant)
# (7, pantie)
# (7, pantine)
# (7, pap)
# (7, pape)
# (7, par)
# (7, pare)
# (7, pas)
# (7, pase)
# (7, pat)
# (7, pate)
# (7, paten)
# (7, patin)
# (7, patine)
# (7, pav)
# (7, pave)
# (7, paven)
# (7, pavin)
# (7, paw)
# (7, pawn)
# (7, pax)
# (7, pay)
# (7, pe)
# (7, pea)
# (7, peag)
# (7, peak)
# (7, peal)
# (7, pean)
# (7, peaning)
# (7, peans)
# (7, pear)
# (7, peas)
# (7, peat)
# (7, peba)
# (7, pec)
# (7, pecan)
# (7, pech)
# (7, peck)
# (7, pecs)
# (7, pectin)
# (7, ped)
# (7, peds)
# (7, pee)
# (7, peed)
# (7, peeing)
# (7, peek)
# (7, peel)
# (7, peen)
# (7, peening)
# (7, peens)
# (7, peep)
# (7, peer)
# (7, pees)
# (7, peg)
# (7, pegh)
# (7, pegs)
# (7, peh)
# (7, pehs)
# (7, pein)
# (7, peinct)
# (7, peined)
# (7, peining)
# (7, peins)
# (7, peise)
# (7, peize)
# (7, pekan)
# (7, peke)
# (7, pekin)
# (7, pekins)
# (7, pela)
# (7, pele)
# (7, pelf)
# (7, pell)
# (7, pelon)
# (7, pelt)
# (7, pen)
# (7, penal)
# (7, penang)
# (7, pence)
# (7, pencil)
# (7, pend)
# (7, pending)
# (7, pends)
# (7, pendu)
# (7, pene)
# (7, pened)
# (7, penes)
# (7, pengo)
# (7, penguin)
# (7, peni)
# (7, penial)
# (7, penie)
# (7, penies)
# (7, penile)
# (7, penill)
# (7, pening)
# (7, penis)
# (7, penk)
# (7, penks)
# (7, penman)
# (7, penmen)
# (7, penna)
# (7, pennae)
# (7, pennal)
# (7, penne)
# (7, penned)
# (7, penner)
# (7, pennes)
# (7, penni)
# (7, pennia)
# (7, pennied)
# (7, pennies)
# (7, pennill)
# (7, pennine)
# (7, penning)
# (7, pennis)
# (7, pennon)
# (7, penny)
# (7, pens)
# (7, pensil)
# (7, pension)
# (7, pent)
# (7, pents)
# (7, peon)
# (7, peons)
# (7, peony)
# (7, pep)
# (7, pepino)
# (7, pepo)
# (7, peps)
# (7, pepsin)
# (7, per)
# (7, perai)
# (7, pere)
# (7, perfin)
# (7, peri)
# (7, peril)
# (7, peris)
# (7, perk)
# (7, perkin)
# (7, perm)
# (7, pern)
# (7, pernio)
# (7, perns)
# (7, perp)
# (7, pert)
# (7, perv)
# (7, pes)
# (7, peso)
# (7, pest)
# (7, pet)
# (7, petit)
# (7, pets)
# (7, petti)
# (7, pew)
# (7, pewit)
# (7, pews)
# (7, pfennig)
# (7, pfui)
# (7, phene)
# (7, phenic)
# (7, phenix)
# (7, pheon)
# (7, phew)
# (7, phi)
# (7, phis)
# (7, phiz)
# (7, pho)
# (7, phon)
# (7, phone)
# (7, pht)
# (7, pi)
# (7, pia)
# (7, pial)
# (7, pian)
# (7, piano)
# (7, pians)
# (7, pias)
# (7, pic)
# (7, pica)
# (7, pice)
# (7, picene)
# (7, picine)
# (7, pick)
# (7, pics)
# (7, pie)
# (7, piece)
# (7, piecen)
# (7, pied)
# (7, pieing)
# (7, pieman)
# (7, piemen)
# (7, piend)
# (7, piends)
# (7, pier)
# (7, piers)
# (7, piert)
# (7, pies)
# (7, piet)
# (7, pieta)
# (7, piets)
# (7, piety)
# (7, piezo)
# (7, pig)
# (7, pigeon)
# (7, pigpen)
# (7, pigs)
# (7, piing)
# (7, pika)
# (7, pike)
# (7, piked)
# (7, piker)
# (7, pikes)
# (7, pikey)
# (7, piki)
# (7, pila)
# (7, pile)
# (7, pilea)
# (7, piled)
# (7, pilei)
# (7, piler)
# (7, piles)
# (7, pili)
# (7, pill)
# (7, pily)
# (7, pima)
# (7, piment)
# (7, pimp)
# (7, pin)
# (7, pina)
# (7, pinang)
# (7, pinas)
# (7, pinbone)
# (7, pincer)
# (7, pinch)
# (7, pindan)
# (7, pinder)
# (7, pine)
# (7, pineal)
# (7, pined)
# (7, pinene)
# (7, pinenes)
# (7, pinery)
# (7, pines)
# (7, pineta)
# (7, piney)
# (7, ping)
# (7, pinged)
# (7, pinger)
# (7, pingle)
# (7, pingo)
# (7, pings)
# (7, pinier)
# (7, pinies)
# (7, pining)
# (7, pinion)
# (7, pinite)
# (7, pink)
# (7, pinked)
# (7, pinken)
# (7, pinkens)
# (7, pinker)
# (7, pinkey)
# (7, pinkie)
# (7, pinko)
# (7, pinks)
# (7, pinky)
# (7, pinna)
# (7, pinnace)
# (7, pinnae)
# (7, pinnal)
# (7, pinnas)
# (7, pinnate)
# (7, pinned)
# (7, pinner)
# (7, pinners)
# (7, pinnet)
# (7, pinnets)
# (7, pinnie)
# (7, pinnies)
# (7, pinnoed)
# (7, pinnule)
# (7, pinny)
# (7, pinole)
# (7, pinon)
# (7, pinones)
# (7, pinons)
# (7, pinot)
# (7, pins)
# (7, pint)
# (7, pinta)
# (7, pintle)
# (7, pinto)
# (7, pints)
# (7, pinup)
# (7, piny)
# (7, pinyin)
# (7, pinyon)
# (7, pion)
# (7, pioned)
# (7, pioner)
# (7, pioney)
# (7, pions)
# (7, piony)
# (7, pioy)
# (7, pioye)
# (7, pip)
# (7, pipa)
# (7, pipe)
# (7, piped)
# (7, piper)
# (7, pipes)
# (7, pipet)
# (7, pipi)
# (7, pips)
# (7, pipy)
# (7, pique)
# (7, pir)
# (7, pirl)
# (7, pirn)
# (7, pirnie)
# (7, pirns)
# (7, pirs)
# (7, pis)
# (7, pise)
# (7, pises)
# (7, pish)
# (7, piso)
# (7, piss)
# (7, piste)
# (7, pit)
# (7, pita)
# (7, pith)
# (7, pitmen)
# (7, piton)
# (7, pits)
# (7, pitten)
# (7, pity)
# (7, piu)
# (7, pium)
# (7, pix)
# (7, pixel)
# (7, pixes)
# (7, pixie)
# (7, pixy)
# (7, pize)
# (7, pized)
# (7, pizes)
# (7, plain)
# (7, plan)
# (7, plane)
# (7, plea)
# (7, pleb)
# (7, pled)
# (7, plena)
# (7, pleon)
# (7, plew)
# (7, plex)
# (7, plie)
# (7, plied)
# (7, plier)
# (7, plies)
# (7, plim)
# (7, pling)
# (7, plink)
# (7, plu)
# (7, plue)
# (7, ply)
# (7, po)
# (7, poa)
# (7, pod)
# (7, poem)
# (7, poep)
# (7, poet)
# (7, poh)
# (7, poi)
# (7, poind)
# (7, point)
# (7, pointe)
# (7, pois)
# (7, poise)
# (7, poke)
# (7, pokie)
# (7, pol)
# (7, pole)
# (7, pom)
# (7, pome)
# (7, ponce)
# (7, pond)
# (7, pone)
# (7, ponent)
# (7, pones)
# (7, poney)
# (7, pong)
# (7, ponied)
# (7, ponies)
# (7, ponk)
# (7, pons)
# (7, pont)
# (7, pontie)
# (7, pontine)
# (7, pony)
# (7, poo)
# (7, poon)
# (7, pop)
# (7, pope)
# (7, pore)
# (7, porn)
# (7, pos)
# (7, pose)
# (7, pot)
# (7, pote)
# (7, potin)
# (7, pow)
# (7, powin)
# (7, pown)
# (7, pownie)
# (7, pox)
# (7, poz)
# (7, pre)
# (7, pree)
# (7, preen)
# (7, preif)
# (7, prem)
# (7, prent)
# (7, prep)
# (7, prex)
# (7, prey)
# (7, prez)
# (7, price)
# (7, pride)
# (7, pried)
# (7, prief)
# (7, prier)
# (7, pries)
# (7, prig)
# (7, prim)
# (7, prime)
# (7, prince)
# (7, prink)
# (7, print)
# (7, prion)
# (7, prise)
# (7, prize)
# (7, pro)
# (7, proin)
# (7, proine)
# (7, prone)
# (7, pruine)
# (7, prune)
# (7, pry)
# (7, psi)
# (7, psion)
# (7, psis)
# (7, pst)
# (7, pterin)
# (7, ptui)
# (7, pub)
# (7, pube)
# (7, puce)
# (7, pud)
# (7, puer)
# (7, pug)
# (7, puh)
# (7, puir)
# (7, puisne)
# (7, puke)
# (7, pul)
# (7, pule)
# (7, puli)
# (7, pumie)
# (7, pun)
# (7, puna)
# (7, punce)
# (7, pung)
# (7, punier)
# (7, punji)
# (7, punk)
# (7, punkie)
# (7, punkin)
# (7, punned)
# (7, punner)
# (7, punnet)
# (7, punnier)
# (7, punny)
# (7, puns)
# (7, punt)
# (7, puny)
# (7, pup)
# (7, pur)
# (7, pure)
# (7, puri)
# (7, purin)
# (7, purine)
# (7, pus)
# (7, put)
# (7, puy)
# (7, pya)
# (7, pye)
# (7, pyeing)
# (7, pyes)
# (7, pyet)
# (7, pyic)
# (7, pyin)
# (7, pyins)
# (7, pyne)
# (7, pyned)
# (7, pynes)
# (7, pyning)
# (7, pyre)
# (7, pyx)
# (7, pyxie)
# (7, qi)
# (7, qis)
# (7, quep)
# (7, quin)
# (7, quine)
# (7, quip)
# (7, rai)
# (7, rain)
# (7, raine)
# (7, ran)
# (7, rani)
# (7, ranine)
# (7, rap)
# (7, rape)
# (7, rapine)
# (7, re)
# (7, rean)
# (7, reap)
# (7, reb)
# (7, rec)
# (7, red)
# (7, redip)
# (7, ree)
# (7, reen)
# (7, ref)
# (7, reg)
# (7, reh)
# (7, rei)
# (7, reif)
# (7, reign)
# (7, reik)
# (7, rein)
# (7, reink)
# (7, reins)
# (7, reis)
# (7, rem)
# (7, ren)
# (7, rend)
# (7, renig)
# (7, renin)
# (7, renins)
# (7, renk)
# (7, renne)
# (7, rennin)
# (7, rens)
# (7, rent)
# (7, reny)
# (7, reo)
# (7, rep)
# (7, repin)
# (7, repine)
# (7, repins)
# (7, repo)
# (7, repp)
# (7, reps)
# (7, res)
# (7, resin)
# (7, ret)
# (7, rev)
# (7, rew)
# (7, rewin)
# (7, rex)
# (7, rez)
# (7, rhine)
# (7, ria)
# (7, rib)
# (7, rice)
# (7, rid)
# (7, ride)
# (7, riel)
# (7, riem)
# (7, rif)
# (7, rife)
# (7, rig)
# (7, rile)
# (7, rim)
# (7, rime)
# (7, rin)
# (7, rind)
# (7, rine)
# (7, rines)
# (7, ring)
# (7, rink)
# (7, rins)
# (7, rinse)
# (7, rip)
# (7, ripe)
# (7, riped)
# (7, ripen)
# (7, ripens)
# (7, riper)
# (7, ripes)
# (7, ripp)
# (7, rips)
# (7, ript)
# (7, rise)
# (7, risen)
# (7, risp)
# (7, rit)
# (7, rite)
# (7, rive)
# (7, riven)
# (7, riz)
# (7, roe)
# (7, roin)
# (7, rone)
# (7, ronin)
# (7, ronne)
# (7, ronnie)
# (7, rope)
# (7, rue)
# (7, ruin)
# (7, run)
# (7, rune)
# (7, rye)
# (7, rype)
# (7, sae)
# (7, sai)
# (7, sain)
# (7, saine)
# (7, san)
# (7, sane)
# (7, sannie)
# (7, sap)
# (7, sdein)
# (7, sea)
# (7, sean)
# (7, sec)
# (7, sed)
# (7, see)
# (7, seen)
# (7, seep)
# (7, seg)
# (7, segni)
# (7, sei)
# (7, seif)
# (7, seik)
# (7, seil)
# (7, seine)
# (7, seir)
# (7, seis)
# (7, sel)
# (7, semi)
# (7, sen)
# (7, sena)
# (7, send)
# (7, sene)
# (7, sengi)
# (7, senna)
# (7, sennit)
# (7, sens)
# (7, sensi)
# (7, sent)
# (7, senti)
# (7, sepia)
# (7, sepic)
# (7, seps)
# (7, sept)
# (7, ser)
# (7, serin)
# (7, set)
# (7, sew)
# (7, sewin)
# (7, sewn)
# (7, sex)
# (7, sey)
# (7, sez)
# (7, sh)
# (7, she)
# (7, shin)
# (7, shine)
# (7, shinne)
# (7, ship)
# (7, si)
# (7, sib)
# (7, sic)
# (7, sice)
# (7, side)
# (7, sien)
# (7, sienna)
# (7, siens)
# (7, sient)
# (7, sies)
# (7, sif)
# (7, sign)
# (7, sik)
# (7, sike)
# (7, sile)
# (7, silen)
# (7, sim)
# (7, simp)
# (7, sin)
# (7, since)
# (7, sind)
# (7, sine)
# (7, sined)
# (7, sines)
# (7, sinew)
# (7, sing)
# (7, singe)
# (7, sinh)
# (7, sink)
# (7, sinned)
# (7, sinner)
# (7, sinnet)
# (7, sins)
# (7, sip)
# (7, sipe)
# (7, siped)
# (7, sipes)
# (7, sips)
# (7, sir)
# (7, sire)
# (7, siren)
# (7, sis)
# (7, sit)
# (7, site)
# (7, six)
# (7, size)
# (7, skein)
# (7, sken)
# (7, skep)
# (7, ski)
# (7, skin)
# (7, skip)
# (7, slip)
# (7, slipe)
# (7, snap)
# (7, sneap)
# (7, sneb)
# (7, sned)
# (7, snee)
# (7, snib)
# (7, snide)
# (7, snies)
# (7, snig)
# (7, snip)
# (7, snipe)
# (7, sniped)
# (7, sniper)
# (7, snipes)
# (7, snips)
# (7, snipy)
# (7, snit)
# (7, snoep)
# (7, sny)
# (7, snye)
# (7, so)
# (7, son)
# (7, sone)
# (7, sonne)
# (7, sop)
# (7, spa)
# (7, spae)
# (7, spain)
# (7, span)
# (7, spane)
# (7, spean)
# (7, spec)
# (7, sped)
# (7, speil)
# (7, speir)
# (7, spek)
# (7, spend)
# (7, spent)
# (7, spet)
# (7, spew)
# (7, spic)
# (7, spice)
# (7, spide)
# (7, spie)
# (7, spied)
# (7, spiel)
# (7, spier)
# (7, spies)
# (7, spif)
# (7, spik)
# (7, spike)
# (7, spile)
# (7, spim)
# (7, spin)
# (7, spina)
# (7, spinae)
# (7, spine)
# (7, spined)
# (7, spinel)
# (7, spines)
# (7, spinet)
# (7, spink)
# (7, spinner)
# (7, spinnet)
# (7, spinney)
# (7, spinny)
# (7, spinone)
# (7, spins)
# (7, spiny)
# (7, spire)
# (7, spit)
# (7, spite)
# (7, spiv)
# (7, spline)
# (7, spue)
# (7, spun)
# (7, spy)
# (7, sri)
# (7, st)
# (7, stein)
# (7, sten)
# (7, step)
# (7, stie)
# (7, stipe)
# (7, sue)
# (7, sui)
# (7, sun)
# (7, sunn)
# (7, sup)
# (7, supe)
# (7, supine)
# (7, swine)
# (7, swipe)
# (7, sye)
# (7, syen)
# (7, syn)
# (7, syne)
# (7, sype)
# (7, ta)
# (7, tae)
# (7, tai)
# (7, tain)
# (7, tan)
# (7, tane)
# (7, tannie)
# (7, tap)
# (7, tape)
# (7, tapen)
# (7, te)
# (7, tea)
# (7, tec)
# (7, ted)
# (7, tee)
# (7, teen)
# (7, tef)
# (7, teg)
# (7, teil)
# (7, teind)
# (7, tel)
# (7, temp)
# (7, tempi)
# (7, ten)
# (7, tend)
# (7, tene)
# (7, tenia)
# (7, tenne)
# (7, tennis)
# (7, tenno)
# (7, tenny)
# (7, tenon)
# (7, tenpin)
# (7, tenpins)
# (7, tens)
# (7, tent)
# (7, tepa)
# (7, tepid)
# (7, tern)
# (7, tes)
# (7, tet)
# (7, tew)
# (7, tex)
# (7, the)
# (7, thein)
# (7, then)
# (7, thin)
# (7, thine)
# (7, ti)
# (7, tic)
# (7, tice)
# (7, tid)
# (7, tide)
# (7, tie)
# (7, tied)
# (7, tiepin)
# (7, tier)
# (7, ties)
# (7, tig)
# (7, tige)
# (7, tike)
# (7, til)
# (7, tile)
# (7, time)
# (7, tin)
# (7, tind)
# (7, tine)
# (7, tinea)
# (7, tined)
# (7, tines)
# (7, ting)
# (7, tinge)
# (7, tink)
# (7, tinmen)
# (7, tinned)
# (7, tinner)
# (7, tinnie)
# (7, tinny)
# (7, tins)
# (7, tint)
# (7, tiny)
# (7, tip)
# (7, tipi)
# (7, tips)
# (7, tipt)
# (7, tire)
# (7, tis)
# (7, tit)
# (7, tite)
# (7, tix)
# (7, to)
# (7, toe)
# (7, ton)
# (7, tone)
# (7, tonne)
# (7, top)
# (7, tope)
# (7, topi)
# (7, trie)
# (7, trin)
# (7, trine)
# (7, trip)
# (7, tripe)
# (7, tui)
# (7, tun)
# (7, tune)
# (7, tup)
# (7, twin)
# (7, twine)
# (7, twp)
# (7, tye)
# (7, tyin)
# (7, tyne)
# (7, type)
# (7, uey)
# (7, ug)
# (7, uh)
# (7, uke)
# (7, ule)
# (7, um)
# (7, ump)
# (7, umpie)
# (7, un)
# (7, unai)
# (7, unbe)
# (7, unce)
# (7, unci)
# (7, unde)
# (7, undine)
# (7, unfine)
# (7, unhip)
# (7, uni)
# (7, union)
# (7, uniped)
# (7, unis)
# (7, unit)
# (7, unite)
# (7, unline)
# (7, unopen)
# (7, unpeg)
# (7, unpen)
# (7, unpens)
# (7, unpent)
# (7, unpile)
# (7, unpin)
# (7, unpins)
# (7, unrein)
# (7, unrip)
# (7, unripe)
# (7, uns)
# (7, untie)
# (7, untin)
# (7, unzip)
# (7, up)
# (7, upend)
# (7, upo)
# (7, upon)
# (7, ups)
# (7, uptie)
# (7, ur)
# (7, ure)
# (7, urine)
# (7, urn)
# (7, urp)
# (7, us)
# (7, use)
# (7, ut)
# (7, ute)
# (7, vae)
# (7, vain)
# (7, van)
# (7, vane)
# (7, vee)
# (7, veep)
# (7, veg)
# (7, veil)
# (7, vein)
# (7, veins)
# (7, veiny)
# (7, vena)
# (7, vend)
# (7, venin)
# (7, venine)
# (7, venins)
# (7, vent)
# (7, vet)
# (7, vex)
# (7, via)
# (7, viae)
# (7, vibe)
# (7, vice)
# (7, vid)
# (7, vide)
# (7, vie)
# (7, vied)
# (7, vier)
# (7, vies)
# (7, view)
# (7, vig)
# (7, vile)
# (7, vim)
# (7, vimen)
# (7, vin)
# (7, vina)
# (7, vine)
# (7, vined)
# (7, viner)
# (7, vines)
# (7, vinew)
# (7, vino)
# (7, vins)
# (7, vint)
# (7, viny)
# (7, viper)
# (7, vire)
# (7, vis)
# (7, vise)
# (7, visne)
# (7, vite)
# (7, vive)
# (7, vixen)
# (7, vlei)
# (7, voe)
# (7, wae)
# (7, wai)
# (7, wain)
# (7, wan)
# (7, wane)
# (7, wap)
# (7, we)
# (7, wean)
# (7, web)
# (7, wed)
# (7, wee)
# (7, ween)
# (7, weep)
# (7, weid)
# (7, weil)
# (7, weir)
# (7, wem)
# (7, wen)
# (7, wena)
# (7, wend)
# (7, wenny)
# (7, wens)
# (7, went)
# (7, wept)
# (7, wet)
# (7, wex)
# (7, wey)
# (7, when)
# (7, whin)
# (7, whine)
# (7, whip)
# (7, wice)
# (7, wide)
# (7, widen)
# (7, wiel)
# (7, wife)
# (7, wig)
# (7, wile)
# (7, wimp)
# (7, win)
# (7, wince)
# (7, wind)
# (7, wine)
# (7, wined)
# (7, wines)
# (7, winey)
# (7, wing)
# (7, winge)
# (7, wink)
# (7, winn)
# (7, winna)
# (7, winned)
# (7, winner)
# (7, winnle)
# (7, winns)
# (7, wino)
# (7, wins)
# (7, winy)
# (7, winze)
# (7, wipe)
# (7, wiped)
# (7, wiper)
# (7, wipes)
# (7, wippen)
# (7, wire)
# (7, wis)
# (7, wise)
# (7, wisp)
# (7, wit)
# (7, wite)
# (7, wive)
# (7, wiz)
# (7, wizen)
# (7, wo)
# (7, woe)
# (7, won)
# (7, wop)
# (7, wren)
# (7, wye)
# (7, wyn)
# (7, wynn)
# (7, xenia)
# (7, xenic)
# (7, xenon)
# (7, xi)
# (7, xis)
# (7, xu)
# (7, ya)
# (7, yae)
# (7, yap)
# (7, ye)
# (7, yea)
# (7, yean)
# (7, yeh)
# (7, yelp)
# (7, yen)
# (7, yens)
# (7, yep)
# (7, yeps)
# (7, yes)
# (7, yet)
# (7, yeti)
# (7, yew)
# (7, yex)
# (7, yid)
# (7, yike)
# (7, yin)
# (7, yince)
# (7, yins)
# (7, yip)
# (7, yipe)
# (7, yipes)
# (7, yips)
# (7, yite)
# (7, ympe)
# (7, yo)
# (7, yon)
# (7, yoni)
# (7, yonnie)
# (7, yu)
# (7, yup)
# (7, za)
# (7, zap)
# (7, zea)
# (7, zed)
# (7, zee)
# (7, zein)
# (7, zeins)
# (7, zek)
# (7, zel)
# (7, zep)
# (7, zeps)
# (7, zex)
# (7, zig)
# (7, zin)
# (7, zinc)
# (7, zine)
# (7, zineb)
# (7, zines)
# (7, zing)
# (7, zinke)
# (7, zins)
# (7, zip)
# (7, zips)
# (7, zit)
# (7, zite)
# (7, ziz)
# (7, zo)
# (7, zone)
# Total number of words: 2734

# %%
""" Produces a list of all words and scores that matches our expectations """
# Autograde cell - do not erase/delete

# The way windows and mac end lines is different 
# - windows adds a \r\n to each line 
# - mac/linux adds just a \n to each line
# The autograder will detect the system platform and use that to determine the 'correct' solution

# The code below is shown here so you know how the autograder works
# Try this block to see if your solution matches
# If your answer looks like it matches but still throws an 'autograder' error, please to double check your answer BUT 
# The purpose of the assignment isn't to make your code match the autograder - if you answer is correct it will be graded so 
# We will check every answer the autograder deems is incorrect

import platform

# test whether your output matches our expectation
cmd = ['python', 'scrabble.py', 'Penguin']
test = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])

if platform.system() == 'Windows':
    solution = '(10, penguin)\r\n(9, pening)\r\n(8, genip)\r\n(8, unpeg)\r\n(7, ingenu)\r\n(7, penni)\r\n(7, ping)\r\n(7, pung)\r\n(7, unpen)\r\n(7, unpin)\r\n(6, gip)\r\n(6, gup)\r\n(6, peg)\r\n(6, pein)\r\n(6, peni)\r\n(6, pig)\r\n(6, pine)\r\n(6, pug)\r\n(5, ennui)\r\n(5, genu)\r\n(5, gien)\r\n(5, ginn)\r\n(5, nep)\r\n(5, nip)\r\n(5, pen)\r\n(5, pie)\r\n(5, pin)\r\n(5, piu)\r\n(5, pun)\r\n(4, eng)\r\n(4, gen)\r\n(4, gie)\r\n(4, gin)\r\n(4, gnu)\r\n(4, gue)\r\n(4, gun)\r\n(4, neg)\r\n(4, nine)\r\n(4, pe)\r\n(4, pi)\r\n(4, up)\r\n(3, gi)\r\n(3, gu)\r\n(3, inn)\r\n(3, nie)\r\n(3, nun)\r\n(3, ug)\r\n(3, uni)\r\n(2, en)\r\n(2, in)\r\n(2, ne)\r\n(2, nu)\r\n(2, un)\r\nTotal number of words: 53\r\n'
else:
    solution = '(10, penguin)\n(9, pening)\n(8, genip)\n(8, unpeg)\n(7, ingenu)\n(7, penni)\n(7, ping)\n(7, pung)\n(7, unpen)\n(7, unpin)\n(6, gip)\n(6, gup)\n(6, peg)\n(6, pein)\n(6, peni)\n(6, pig)\n(6, pine)\n(6, pug)\n(5, ennui)\n(5, genu)\n(5, gien)\n(5, ginn)\n(5, nep)\n(5, nip)\n(5, pen)\n(5, pie)\n(5, pin)\n(5, piu)\n(5, pun)\n(4, eng)\n(4, gen)\n(4, gie)\n(4, gin)\n(4, gnu)\n(4, gue)\n(4, gun)\n(4, neg)\n(4, nine)\n(4, pe)\n(4, pi)\n(4, up)\n(3, gi)\n(3, gu)\n(3, inn)\n(3, nie)\n(3, nun)\n(3, ug)\n(3, uni)\n(2, en)\n(2, in)\n(2, ne)\n(2, nu)\n(2, un)\nTotal number of words: 53\n'

print("\nDoes your output match our expectation?", test == solution)
# Out:
# Does your output match our expectation? True

# %%
""" The code should run in less than 30 seconds """
# Autograde cell - do not erase/delete

import time
start = time.time()

#test the code in the command line
cmd = ['python', 'scrabble.py', 'PENGU*?']
out = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])

tot_time = time.time() - start
print('Total time was {} seconds'.format(tot_time))
assert_less(tot_time, 30)
# Out:
# Total time was 16.49393892288208 seconds

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
"""Implement extra credit call run the code here
   If this cell isnt filled out - we'll assume the extra credit wasn't done
   Please write a comment on how to use your extra credit syntax and any assumptions also!
"""

# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## If you have feedback for this homework, please submit it using the link below:
#
# http://goo.gl/forms/74yCiQTf6k
